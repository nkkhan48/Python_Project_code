# %%
import pymysql
import pandas as pd

connect1= pymysql.connect(host = 'localhost',
                user = 'root',
                password ='nazim@123',
                database = 'hms')

mcursor=connect1.cursor()

# if mcursor:
#     print("connected")
# else:
#     print("not connected")
print("**************************WELCOME TO NAZIM HOTEL SYSTEM**************************")


def booking_input():
    cid=input("enter the customer id----->")
    check_in=input("enter the check in date----->")
    check_out=input("enter the check out date----->")
    query="INSERT INTO booking_record values ('{}','{}','{}')".format(cid,check_in,check_out)
    mcursor.execute(query)
    connect1.commit()
    print("booking accept successfully")
       
def c_details():
    cid=input("enter the customer id----->")
    c_name=input("enter the customer name----->")
    c_address=input("enter the customer address----->")
    c_age=input("enter the customer age----->")
    c_country=input("enter the customer country----->")
    p_no=input("enter the customer phone number----->")
    c_email=input("enter the customer email----->")
    
    query1="INSERT INTO c_details values ('{}','{}','{}','{}','{}','{}','{}')".format(cid,c_name,c_address,c_age,c_country,p_no,c_email)
    mcursor.execute(query1)
    connect1.commit()
    print("Customer added sucessfully !!")    
    
 
     
def edit_booking():
    x = int(input("Enter the customer ID----->"))
    query2="SELECT*FROM booking_record WHERE cid={}".format(x)
    mcursor.execute(query2)
    
    
    r = mcursor.fetchone()
    if r:
        y = input("Enter New check-out----->")
        query3 = "UPDATE booking_record SET check_out='{}' WHERE cid={}".format(y,x)
        mcursor.execute(query3)
        connect1.commit()
        print("edited successfully")
    else:
        print("Invalid customer ID")
        
def delete_booking():
    x = int(input("Enter the customer ID----->"))
    query4="SELECT*FROM booking_record WHERE cid={}".format(x)
    mcursor.execute(query4)
    
    r = mcursor.fetchone()
    if r:
        query5="DELETE FROM booking_record WHERE cid={}".format(x)
        mcursor.execute(query5)
        connect1.commit()
        print("booking delete successfully")
    else:
        print("Invalid customer ID")

def edit_customer():
    x=int(input("enter the customer ID----->"))
    query6="SELECT*FROM c_details WHERE cid={}".format(x)
    mcursor.execute(query6)
    
    
    r = mcursor.fetchone()
    if r:
        y=input("enter new name for customer----->")
        query7 = "UPDATE c_details SET c_name='{}' WHERE cid={}".format(y,x)
        mcursor.execute(query7)
        connect1.commit()
        print("edited successfully")
    else:
        print("Invalid customer ID")
            
def customer_delete():
    x = int(input("enter the customer ID----->"))
    query8="SELECT*FROM c_details WHERE cid={}".format(x)
    mcursor.execute(query8)
    
    r=mcursor.fetchone()
    if r:
        query9="DELETE FROM c_details WHERE cid={}".format(x)
        mcursor.execute(query9)
        connect1.commit()
        print("customer delete successfully")
    else:
        print("Invalid customer ID")
            
def customer_search():
    x = int(input("enter the customer ID----->"))
    query10="SELECT*FROM c_details WHERE cid={}".format(x)
    mcursor.execute(query10)
    
    r = mcursor.fetchone()
    if r:
        book_df = pd.read_sql(query10, connect1)
        print(book_df)
    else:
        print("Invalid customer ID")

def fashion():
    cid=input("enter the customer id----->")
    dress=input("enter the dress name---->")
    quantity=int(input("enter the dress quantity---->"))
    amount=int(input("enter the amount of dress------>"))
    bill=quantity*amount
    
    query11="INSERT INTO fashion values ('{}','{}',{},{},{})".format(cid,dress,quantity,amount,bill)
    mcursor.execute(query11)
    connect1.commit()
    print("total bill for dress ----->",bill)
    print("sale sucessfully !!")
     
    
def edit_dress():
    x = int(input("enter the customer ID----->"))
    query12="SELECT*FROM fashion WHERE cid={}".format(x)
    mcursor.execute(query12)
    
    r=mcursor.fetchone()
    if r:
        y=input("ente the new name of dress---->")
        query13="UPDATE fashion set dress='{}' WHERE cid={}".format(y,x)
        mcursor.execute(query13)
        connect1.commit()
        print("dress edited successfully")
    else:
        print("Invalid customer ID")

def delete_dress():
    x = int(input("enter the customer ID----->"))
    query14="SELECT*FROM fashion WHERE cid={}".format(x)
    mcursor.execute(query14)
    
    r=mcursor.fetchone()
    if r:
        query15="DELETE FROM  fashion WHERE cid={}".format(x)
        mcursor.execute(query15)
        connect1.commit()
        print("dress delete successfully")
    else:
        print("Invalid customer ID")
        
        
def game_zone():
    cid=input("enter the customer id----->")
    games=input("enter the game name---->")
    hours=int(input("enter the hours for playing---->"))
    amount=int(input("enter the amount of games------>"))
    bill=hours*amount
    query16="INSERT INTO gaming values ('{}','{}',{},{},{})".format(cid,games,hours,amount,bill)
    mcursor.execute(query16)
    connect1.commit()
    print("total bill for games----->",bill)

def rest_zone():
    cid=input("enter the customer id----->")
    cuisine=input("enter the cuisine name---->")
    quntity=int(input("enter the quantity---->"))
    amount=int(input("enter the amount of cuisine------>"))
    bill=quntity*amount
    query17="INSERT INTO restaurent values ('{}','{}',{},{},{})".format(cid,cuisine,quntity,amount,bill)
    mcursor.execute(query17)
    connect1.commit()
    print("total bill for cuisine----->",bill)
    

def room_zone():
    cid=input("enter the customer id----->")
    room_type=input("enter the room type---->")
    no_of_days=int(input("enter the living days---->"))
    room_rent=int(input("enter the room rent------>"))
    bill=no_of_days*room_rent
    query18="INSERT INTO room_rent values ('{}','{}',{},{},{})".format(cid,room_type,no_of_days,room_rent,bill)
    mcursor.execute(query18)
    connect1.commit()
    print("total bill for room rent----->",bill)    

def edit_room():
    x = int(input("enter the customer ID----->"))
    query19="SELECT*FROM room_rent WHERE cid={}".format(x)
    mcursor.execute(query19)
    
    r=mcursor.fetchone()
    if r:
        y=input("ente the new room type---->")
        query20="UPDATE room_rent set room_type='{}' WHERE cid={}".format(y,x)
        mcursor.execute(query20)
        connect1.commit()
        print("room edited successfully")
    else:
        print("Invalid customer ID")
    
def delete_room():
    x = int(input("enter the customer ID----->"))
    query21="SELECT*FROM room_rent WHERE cid={}".format(x)
    mcursor.execute(query14)
    
    r=mcursor.fetchone()
    if r:
        query22="DELETE FROM  room_rent WHERE cid={}".format(x)
        mcursor.execute(query22)
        connect1.commit()
        print("room delete successfully")
    else:
        print("Invalid customer ID")
           
    
while True:
    print("""
    Enter your choice
    1. Booking
    2. Customer Details
    3. Fashion store 
    4. Gaming 
    5. Restaurent 
    6. Room Rent 
    7. Exits!!!
    """)
     
    choice = int(input())
    if choice==1:
        while True:
            print("**************************WELCOME TO BOOKING SYSTEM**************************")
            print("""
             Enter your choice !!!
             1. Customer booking
             2. Add customer 
             2. edit_booking
             3. delete_booking
             4. Back to Main Menu
            """)
            ch = int(input())
            if ch==1:
                booking_input()
            elif ch==2:
                c_details()
            elif ch==2:
                edit_booking()
            elif ch==3:
                delete_booking()
            elif ch==4:
                break
    elif choice==2:
        while True:
            print("**************************WELCOME TO CUSTOMER DETAILS SYSTEM**************************")
            print("""
             Enter your choice !!!
             1. Edit Customer details
             2. Delete a Customer 
             3. Search a Customer
             4. Back to main menu 
            """)
            ch = int(input())
            if ch==1:
                edit_customer()
            elif ch==2:
                customer_delete()
            elif ch==3:
                customer_search()
            elif ch==4:
                break
    elif choice==3:
        while True:
            print("**************************WELCOME TO FASHION STORE SYSTEM**************************")
            print("""
            Enter your choice!!!
            1.Purchased Dress
            2.edit dress
            3.delete dress
            4.Back to menu
            """)
            ch = int(input())
            if ch==1:
                fashion()
            elif ch==2:
                edit_dress()
            elif ch==3:
                delete_dress()
            elif ch==4:
                break
    elif choice==4:
        while True:
            print("**************************WELCOME TO GAMING SYSTEM**************************")
            print("""
            Enter your choice!!!
            1.GAMING BILL
            2.Back to menu
            """)
            ch = int(input())
            if ch==1:
                game_zone()
            elif ch==2:
                break
    elif choice==5:
        while True:
            print("**************************WELCOME TO RESTAURENT SYSTEM**************************")
            print("""
            Enter your choice!!!
            1.Restaurent BILL
            2.Back to menu
            """)
            ch = int(input())
            if ch==1:
                rest_zone()
            elif ch==2:
                break
    elif choice==6:
        while True:
            print("**************************WELCOME TO ROOM RENT SYSTEM**************************")
            print("""
            Enter your choice!!!
            1.Room Rent
            2.Edit room
            3.Delete room
            4.Back to menu
            """)
            ch = int(input())
            if ch==1:
                room_zone()
            elif ch==2:
                edit_room()
            elif ch==3:
                delete_room()
            elif ch==4:
                break

            
    elif choice==7:
        print("**************************THANKYOU FOR USING NAZIM HOTEL SYSETM**************************")
        break
# Out:
# **************************WELCOME TO NAZIM HOTEL SYSTEM**************************
#
#     Enter your choice
#     1. Booking
#     2. Customer Details
#     3. Fashion store
#     4. Gaming
#     5. Restaurent
#     6. Room Rent
#     7. Exits!!!
#
# 1
# **************************WELCOME TO BOOKING SYSTEM**************************
#
#              Enter your choice !!!
#              1. Customer booking
#              2. Add customer
#              2. edit_booking
#              3. delete_booking
#              4. Back to Main Menu
#
# 1
# enter the customer id----->7
# enter the check in date----->2023-04-30
# enter the check out date----->2023-05-06
# booking accept successfully
# **************************WELCOME TO BOOKING SYSTEM**************************
#
#              Enter your choice !!!
#              1. Customer booking
#              2. Add customer
#              2. edit_booking
#              3. delete_booking
#              4. Back to Main Menu
#
# 2
# ...
